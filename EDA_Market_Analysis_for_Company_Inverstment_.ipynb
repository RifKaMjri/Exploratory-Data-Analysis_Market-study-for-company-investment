# %% [markdown]
# # Import necessary libraries for reading and extracting datasets details

# %%
# %matplotlib inline
import seaborn as sns
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot  as plt
import plotly.express as px

# %%
#Let's read the 4 files using pandas libraries
cab_data = pd.read_csv("RefkaMejri/DataSets-main/Cab_Data.csv")
TransactionID_data = pd.read_csv("RefkaMejri/DataSets-main/Transaction_ID.csv")
City_data = pd.read_csv("RefkaMejri/DataSets-main/City.csv")
CustomerID_data = pd.read_csv("RefkaMejri/DataSets-main/Customer_ID.csv")

# %% [markdown]
# # cab_data details

# %%
cab_data
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# 1              28.62         358.52      334.8540
# ...

# %%
cab_data.dtypes
# Out:
# Transaction ID      int64
# Date of Travel      int64
# Company            object
# City               object
# KM Travelled      float64
# Price Charged     float64
# Cost of Trip      float64
# dtype: object

# %%
cab_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  int64
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 19.2+ MB

# %%
cab_data.describe()
# Out:
#        Transaction ID  Date of Travel   KM Travelled  Price Charged  \
# count    3.593920e+05   359392.000000  359392.000000  359392.000000
# mean     1.022076e+07    42964.067998      22.567254     423.443311
# std      1.268058e+05      307.467197      12.233526     274.378911
# min      1.000001e+07    42371.000000       1.900000      15.600000
# 25%      1.011081e+07    42697.000000      12.000000     206.437500
# 50%      1.022104e+07    42988.000000      22.440000     386.360000
# 75%      1.033094e+07    43232.000000      32.960000     583.660000
# max      1.044011e+07    43465.000000      48.000000    2048.030000
#
#         Cost of Trip
# count  359392.000000
# mean      286.190113
# std       157.993661
# min        19.000000
# 25%       151.200000
# 50%       282.480000
# 75%       413.683200
# max       691.200000

# %%
# %%time

from datetime import datetime
import xlrd

cab_data['Date of Travel'] = cab_data['Date of Travel'].apply(lambda s: xlrd.xldate.xldate_as_datetime(s, 0))
# Out:
# CPU times: user 1.04 s, sys: 39 ms, total: 1.08 s
# Wall time: 1.08 s

# %%
cab_data
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     2016-01-08    Pink Cab     ATLANTA GA
# 1             10000012     2016-01-06    Pink Cab     ATLANTA GA
# 2             10000013     2016-01-02    Pink Cab     ATLANTA GA
# 3             10000014     2016-01-07    Pink Cab     ATLANTA GA
# 4             10000015     2016-01-03    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101     2018-01-08  Yellow Cab  WASHINGTON DC
# 359388        10440104     2018-01-04  Yellow Cab  WASHINGTON DC
# 359389        10440105     2018-01-05  Yellow Cab  WASHINGTON DC
# 359390        10440106     2018-01-05  Yellow Cab  WASHINGTON DC
# 359391        10440107     2018-01-02  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# 1              28.62         358.52      334.8540
# ...

# %% [markdown]
# # Transaction_Id dataset details

# %%
TransactionID_data
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 0             10000011        29290         Card
# 1             10000012        27703         Card
# 2             10000013        28712         Cash
# 3             10000014        28020         Cash
# 4             10000015        27182         Card
# ...                ...          ...          ...
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card
#
# [440098 rows x 3 columns]

# %%
TransactionID_data.describe()
# Out:
#        Transaction ID    Customer ID
# count    4.400980e+05  440098.000000
# mean     1.022006e+07   23619.513120
# std      1.270455e+05   21195.549816
# min      1.000001e+07       1.000000
# 25%      1.011004e+07    3530.000000
# 50%      1.022006e+07   15168.000000
# 75%      1.033008e+07   43884.000000
# max      1.044011e+07   60000.000000

# %%
TransactionID_data.dtypes
# Out:
# Transaction ID     int64
# Customer ID        int64
# Payment_Mode      object
# dtype: object

# %%
TransactionID_data.shape
# Out:
# (440098, 3)

# %%
TransactionID_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  440098 non-null  int64
#  1   Customer ID     440098 non-null  int64
#  2   Payment_Mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB

# %%
CustomerID_data
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 0            29290    Male   28               10813
# 1            27703    Male   27                9237
# 2            28712    Male   53               11242
# 3            28020    Male   23               23327
# 4            27182    Male   33                8536
# ...            ...     ...  ...                 ...
# 49166        12490    Male   33               18713
# 49167        14971    Male   30               15346
# 49168        41414    Male   38                3960
# 49169        41677    Male   23               19454
# 49170        39761  Female   32               10128
#
# [49171 rows x 4 columns]

# %%
CustomerID_data.describe()
# Out:
#         Customer ID           Age  Income (USD/Month)
# count  49171.000000  49171.000000        49171.000000
# mean   28398.252283     35.363121        15015.631856
# std    17714.137333     12.599066         8002.208253
# min        1.000000     18.000000         2000.000000
# 25%    12654.500000     25.000000         8289.500000
# 50%    27631.000000     33.000000        14656.000000
# 75%    43284.500000     42.000000        21035.000000
# max    60000.000000     65.000000        35000.000000

# %%
CustomerID_data.shape
# Out:
# (49171, 4)

# %%
CustomerID_data.dtypes
# Out:
# Customer ID            int64
# Gender                object
# Age                    int64
# Income (USD/Month)     int64
# dtype: object

# %%
CustomerID_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %% [markdown]
# # City_data details

# %%
City_data
# Out:
#                 City   Population      Users
# 0        NEW YORK NY   8,405,837    302,149
# 1         CHICAGO IL   1,955,130    164,468
# 2     LOS ANGELES CA   1,595,037    144,132
# 3           MIAMI FL   1,339,155     17,675
# 4     SILICON VALLEY   1,177,609     27,247
# 5      ORANGE COUNTY   1,030,185     12,994
# 6       SAN DIEGO CA     959,307     69,995
# 7         PHOENIX AZ     943,999      6,133
# 8          DALLAS TX     942,908     22,157
# 9         ATLANTA GA     814,885     24,701
# 10         DENVER CO     754,233     12,421
# 11         AUSTIN TX     698,371     14,978
# 12        SEATTLE WA     671,238     25,063
# 13         TUCSON AZ     631,442      5,712
# 14  SAN FRANCISCO CA     629,591    213,609
# 15     SACRAMENTO CA     545,776      7,044
# 16     PITTSBURGH PA     542,085      3,643
# 17     WASHINGTON DC     418,859    127,001
# 18      NASHVILLE TN     327,225      9,270
# 19         BOSTON MA     248,968     80,021

# %%
City_data.describe()
# Out:
#                City   Population      Users
# count            20           20         20
# unique           20           20         20
# top     NEW YORK NY   8,405,837    302,149
# freq              1            1          1

# %%
City_data.shape
# Out:
# (20, 3)

# %%
City_data.dtypes
# Out:
# City          object
# Population    object
# Users         object
# dtype: object

# %%
City_data['Population'] = [x.replace(',','') for x in City_data['Population']]
City_data['Population'] = City_data['Population'].astype(float)

# %%
City_data['Users'] = [x.replace(',','') for x in City_data['Users']]
City_data['Users'] = City_data['Users'].astype(float)

# %%
#Let's merge all datasets
Merged_data = cab_data.merge(TransactionID_data, on= 'Transaction ID').merge(CustomerID_data, on ='Customer ID').merge(City_data, on = 'City')

# %%
Merged_data
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     2016-01-08    Pink Cab     ATLANTA GA
# 1             10351127     2018-07-21  Yellow Cab     ATLANTA GA
# 2             10412921     2018-11-23  Yellow Cab     ATLANTA GA
# 3             10000012     2016-01-06    Pink Cab     ATLANTA GA
# 4             10320494     2018-04-21  Yellow Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10307228     2018-03-03  Yellow Cab  WASHINGTON DC
# 359388        10319775     2018-04-13  Yellow Cab  WASHINGTON DC
# 359389        10347676     2018-07-06  Yellow Cab  WASHINGTON DC
# 359390        10358624     2018-08-02  Yellow Cab  WASHINGTON DC
# 359391        10370709     2018-08-30  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip  Customer ID Payment_Mode  \
# 0              30.45         370.95      313.6350        29290         Card
# ...

# %%
Merged_data.dtypes
# Out:
# Transaction ID                 int64
# Date of Travel        datetime64[ns]
# Company                       object
# City                          object
# KM Travelled                 float64
# Price Charged                float64
# Cost of Trip                 float64
# Customer ID                    int64
# Payment_Mode                  object
# Gender                        object
# Age                            int64
# Income (USD/Month)             int64
# Population                   float64
# Users                        float64
# dtype: object

# %%
Merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359392 entries, 0 to 359391
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Transaction ID      359392 non-null  int64
#  1   Date of Travel      359392 non-null  datetime64[ns]
#  2   Company             359392 non-null  object
#  3   City                359392 non-null  object
#  4   KM Travelled        359392 non-null  float64
#  5   Price Charged       359392 non-null  float64
#  6   Cost of Trip        359392 non-null  float64
#  7   Customer ID         359392 non-null  int64
#  8   Payment_Mode        359392 non-null  object
#  9   Gender              359392 non-null  object
#  10  Age                 359392 non-null  int64
#  11  Income (USD/Month)  359392 non-null  int64
#  12  Population          359392 non-null  float64
#  13  Users               359392 non-null  float64
# ...

# %%
Merged_data.shape
# Out:
# (359392, 14)

# %%
Merged_data.describe()
# Out:
#        Transaction ID   KM Travelled  Price Charged   Cost of Trip  \
# count    3.593920e+05  359392.000000  359392.000000  359392.000000
# mean     1.022076e+07      22.567254     423.443311     286.190113
# std      1.268058e+05      12.233526     274.378911     157.993661
# min      1.000001e+07       1.900000      15.600000      19.000000
# 25%      1.011081e+07      12.000000     206.437500     151.200000
# 50%      1.022104e+07      22.440000     386.360000     282.480000
# 75%      1.033094e+07      32.960000     583.660000     413.683200
# max      1.044011e+07      48.000000    2048.030000     691.200000
#
#          Customer ID            Age  Income (USD/Month)    Population  \
# count  359392.000000  359392.000000       359392.000000  3.593920e+05
# mean    19191.652115      35.336705        15048.822937  3.132198e+06
# std     21012.412463      12.594234         7969.409482  3.315194e+06
# min         1.000000      18.000000         2000.000000  2.489680e+05
# ...

# %% [markdown]
# # EDA

# %%
#1_Data_Cleaning

# %%
#Missing values?
Merged_data.isnull().sum()
# Out:
# Transaction ID        0
# Date of Travel        0
# Company               0
# City                  0
# KM Travelled          0
# Price Charged         0
# Cost of Trip          0
# Customer ID           0
# Payment_Mode          0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# Population            0
# Users                 0
# dtype: int64

# %%
#Duplication?
duplicaton = Merged_data[Merged_data.duplicated()]
duplicaton
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Date of Travel, Company, City, KM Travelled, Price Charged, Cost of Trip, Customer ID, Payment_Mode, Gender, Age, Income (USD/Month), Population, Users]
# Index: []

# %%
#Let's verify correlation between features after analyzing outliers and analyzing histogram
#Plot features correlation
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(Merged_data.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12);
# save heatmap as .png file
plt.savefig('heatmap.png', dpi=300, bbox_inches='tight')

# %%
plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(Merged_data.corr()[['Price Charged']].sort_values(by='Price Charged', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with Price Charged', fontdict={'fontsize':18}, pad=16);

# %%
plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(Merged_data.corr()[['Cost of Trip']].sort_values(by='Cost of Trip', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating Cost of Trip', fontdict={'fontsize':18}, pad=16);

# %%
plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(Merged_data.corr()[['KM Travelled']].sort_values(by='KM Travelled', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating KM Travelled', fontdict={'fontsize':18}, pad=16);

# %%
#km travelled Distribution
plt.figure(figsize=(8,7))
ax=sns.histplot(data=Merged_data, x="KM Travelled",bins=40, color= 'r')
plt.title('Distribution_of_KM_Travelled', fontsize=12)
plt.ylabel('Frequency')
plt.xlabel('Km_Travelled')
# Out:
# Text(0.5, 0, 'Km_Travelled')

# %%
#Price charged distribution
plt.figure(figsize=(8,7))
ax=sns.histplot(data=Merged_data, x="Price Charged",bins=40, color= 'r')
plt.title('Distribution_of_Price_Charged', fontsize=12)
plt.ylabel('Frequency')
plt.xlabel('Price_Charged')
# Out:
# Text(0.5, 0, 'Price_Charged')

# %%
#Cost of Trip Distribution
plt.figure(figsize=(8,7))
ax=sns.histplot(data=Merged_data, x="Cost of Trip",bins=40, color= 'r')
plt.title('Distribution of the cost_of_trip', fontsize=12)
plt.ylabel('Frequency')
plt.xlabel('Cost of Trip')
# Out:
# Text(0.5, 0, 'Cost of Trip')

# %%
PinkCab = Merged_data[Merged_data['Company']=='Pink Cab']
YellowCab = Merged_data[Merged_data['Company']=='Yellow Cab']

# %%
ax = sns.boxplot(x="Company",y="Price Charged", data=Merged_data, palette=["#ff81c0","#ffff14"])

# %%
ax = sns.boxplot(x="Company",y="Cost of Trip", data=Merged_data, palette=["#ff81c0","#ffff14"])

# %%
plt.figure(figsize=(7,6))
ax=sns.histplot(data=PinkCab, x="KM Travelled",bins=30, color= 'pink')
plt.title('Distribution_of_KM_Travelled', fontsize=10)
plt.ylabel('Frequency')
plt.xlabel('Km Travelled')
plt.figure(figsize=(7,6))
ax=sns.histplot(data=YellowCab, x="KM Travelled",bins=30, color= 'Yellow')
plt.title('Distribution_of_KM_Travelled', fontsize=10)
plt.ylabel('Frequency')
plt.xlabel('Km Travelled')
# Out:
# Text(0.5, 0, 'Km Travelled')

# %%
plt.figure(figsize=(7,6))
ax=sns.histplot(data=PinkCab, x="Price Charged",bins=30, color= 'pink')
plt.title('Distribution_of_Price_Charged', fontsize=10)
plt.ylabel('Frequency')
plt.xlabel('Price_Charged')
plt.figure(figsize=(7,6))
ax=sns.histplot(data=YellowCab, x="Price Charged",bins=30, color= 'Yellow')
plt.title('Distribution_of_Price_Charged', fontsize=10)
plt.ylabel('Frequency')
plt.xlabel('Price_Charged')
# Out:
# Text(0.5, 0, 'Price_Charged')

# %%
plt.figure(figsize=(7,6))
ax=sns.histplot(data=PinkCab, x="Cost of Trip",bins=30, color= 'pink')
plt.title('Distribution_of_Cost_Of_Trip', fontsize=10)
plt.ylabel('Frequency')
plt.xlabel('Cost of Trip')
plt.figure(figsize=(7,6))
ax=sns.histplot(data=YellowCab, x="Cost of Trip",bins=30, color= 'Yellow')
plt.title('Distribution_of_Cost_of_Trip', fontsize=10)
plt.ylabel('Frequency')
plt.xlabel('Cost of Trip')
# Out:
# Text(0.5, 0, 'Cost of Trip')

# %% [markdown]
# # Our Data Analysis study will have focus on customers and users clients of Pink as well as Yellow cab

# %% [markdown]
# # Gender users repartition

# %%
plt.figure(figsize=(7,7))
sns.countplot(data=Merged_data, x="Gender",  palette=["#0343df","#ff796c"])
plt.title('Users', fontsize=20)
plt.ylabel('Frequency')
plt.xlabel('sex')
# Out:
# Text(0.5, 0, 'sex')

# %%
plt.figure(figsize=(7,7))
ax = sns.countplot(x="Company", hue="Gender", data=Merged_data,palette=["#0343df","#ff796c"])
plt.title('Cab users in both companies', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Cab users in both companies')

# %%
Merged_data
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     2016-01-08    Pink Cab     ATLANTA GA
# 1             10351127     2018-07-21  Yellow Cab     ATLANTA GA
# 2             10412921     2018-11-23  Yellow Cab     ATLANTA GA
# 3             10000012     2016-01-06    Pink Cab     ATLANTA GA
# 4             10320494     2018-04-21  Yellow Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10307228     2018-03-03  Yellow Cab  WASHINGTON DC
# 359388        10319775     2018-04-13  Yellow Cab  WASHINGTON DC
# 359389        10347676     2018-07-06  Yellow Cab  WASHINGTON DC
# 359390        10358624     2018-08-02  Yellow Cab  WASHINGTON DC
# 359391        10370709     2018-08-30  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip  Customer ID Payment_Mode  \
# 0              30.45         370.95      313.6350        29290         Card
# ...

# %% [markdown]
# # Checking customers distribution per city

# %%
city_users = Merged_data.groupby('City').agg({"Users":"count"})
city_users.reset_index(inplace=True)
fig = px.pie(city_users, values='Users', names='City', title='Percentage of Users per cities ')
fig.show('png')

# %% [markdown]
# # Transaction repartition per city for the pink as well as the yellow Company

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

city_p = Merged_data[Merged_data.Company=='Pink Cab'].groupby('City').agg({"Customer ID": "count"})
city_p.reset_index(inplace=True)
city_y = Merged_data[Merged_data.Company=='Yellow Cab'].groupby('City').agg({"Customer ID": "count"})
city_y.reset_index(inplace=True)
#this line to specific to create two pie charts
fig = make_subplots(rows=1, cols=2, specs=[[{"type": "pie"}, {"type": "pie"}]],
                    subplot_titles=("PinkCab", " YellowCab") )

# add information
pie1 = px.pie(city_p, values='Customer ID', names='City', 
              title='Percentage of Users in different cities ')
pie2 = px.pie(city_y, values='Customer ID', names='City', 
              title='Percentage of Users in different cities ')

#Location of subplots
for trace in pie1.data:
    fig.add_trace(trace, 1, 1)
for trace in pie2.data:
    fig.add_trace(trace, 1, 2)
# Options of bar chart

fig.update_layout(title_text='Percentage of Customers per City for both Yellow and Pink Cab')
fig.show('png')

# %% [markdown]
# # Price Charged percentage per Gender Custumer in both companies

# %%
import matplotlib.pyplot as plt
price_y=Merged_data[Merged_data.Company=='Yellow Cab'].groupby('Gender').agg({"Price Charged":"mean"})
price_p=Merged_data[Merged_data.Company=='Pink Cab'].groupby('Gender').agg({"Price Charged":"mean"})

#Reset index to column
price_y.reset_index(inplace=True)
price_p.reset_index(inplace=True)


#Create plot
fig = make_subplots(rows=1, cols=2, specs=[[{"type": "pie"}, {"type": "pie"}]],
                    subplot_titles=("Yellow Cab", "Pink Cab "))


pie_1 = px.pie(price_y, values='Price Charged', names='Gender', 
              title='Price Charged based on Men and Women')
pie_2 = px.pie(price_p, values='Price Charged', names='Gender', 
              title='Price Charged based on  Men and Women ')

#Location of subplots
for trace in pie_1.data:
    fig.add_trace(trace, 1, 1)
for trace in pie_2.data:
    fig.add_trace(trace, 1, 2)
# Options of bar chart
fig.update_layout(title_text='Price Charged for each gender for Yellow and Pink Cab')
fig.show('png')

# %% [markdown]
# # Extraction of date info per period(month, year and date)

# %%
Merged_data['year'] = Merged_data['Date of Travel'].dt.year
Merged_data['month'] = Merged_data['Date of Travel'].dt.month
Merged_data['date'] = Merged_data['Date of Travel'].dt.day

# %%
#Let's replace spaces in columns names with _

Merged_data.columns = [col.strip().replace(' ', '_').lower() for col in Merged_data.columns]
print(Merged_data.columns)
# Out:
# Index(['transaction_id', 'date_of_travel', 'company', 'city', 'km_travelled',
#        'price_charged', 'cost_of_trip', 'customer_id', 'payment_mode',
#        'gender', 'age', 'income_(usd/month)', 'population', 'users', 'year',
#        'month', 'date'],
#       dtype='object')

# %%
PinkCab= Merged_data[Merged_data['company']=='Pink Cab']
YellowCab = Merged_data[Merged_data['company']=='Yellow Cab']

# %% [markdown]
# # Transaction repartion per number of each company per year

# %%
plot1 = PinkCab.groupby('year').transaction_id.count()
plot2 = YellowCab.groupby('year').transaction_id.count()
plt.figure(figsize=(7,7))
ax = plt.subplot(111)
ax.bar(plot1.index-0.2, plot1.values, width=0.4, color='pink', align='center',label='Pink Cab')
ax.bar(plot2.index+0.2, plot2.values, width=0.4, color='yellow', align='center',label='Yellow Cab')
plt.title('Transaction Number of YellowCab and PinkCab per year')
plt.ylabel('Transactions Numbers')
plt.xlabel('year')
plt.legend()
plt.show()

# %% [markdown]
# # Transactions repartition per number of each company per month

# %%
plot1 = PinkCab.groupby('month').transaction_id.count()
plot2 = YellowCab.groupby('month').transaction_id.count()
plt.figure(figsize=(14,6))
ax = plt.subplot(111)
ax.bar(plot1.index-0.2, plot1.values, width=0.4, color='pink', align='center',label='Pink Cab')
ax.bar(plot1.index+0.2, plot2.values, width=0.4, color='yellow', align='center',label='Yellow Cab')
plt.title(' Transactions repartition per number of each company per month')
plt.ylabel('Transactions per number')
plt.xlabel('Month')
plt.legend()
plt.show()

# %%
#Customer behavior analysis
ren_df = Merged_data.groupby(['company', 'customer_id']).agg({"users":"count"}).reset_index()
fig = px.histogram(ren_df, x="users", color= "company", barmode='group', title="User Retention",
             color_discrete_map={'(?)':'black', 'Pink Cab':'#FC1CBF', 'Yellow Cab':'#FBE426'})
fig.update_yaxes(title_text='Count of Users')
fig.update_xaxes(title_text='Number of trips')
fig.show('png')

# %% [markdown]
# # Feature Engineering/Adding new feature :
#     Profit feature = Price charged - cost of trips

# %%
Merged_data['Profit'] = Merged_data['price_charged'] - Merged_data['cost_of_trip']

# %% [markdown]
# Features correlation verification

# %%
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(Merged_data.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12);
# save heatmap as .png file
# dpi - sets the resolution of the saved image in dots/inches
# bbox_inches - when set to 'tight' - does not allow the labels to be cropped
plt.savefig('heatmap.png', dpi=300, bbox_inches='tight')

# %%
#Related to the correlation matrix we extract the more significant features
Merged_data[['km_travelled', 'price_charged', 'cost_of_trip', 'Profit']].describe().T
# Out:
#                   count        mean         std     min       25%      50%  \
# km_travelled   359392.0   22.567254   12.233526    1.90   12.0000   22.440
# price_charged  359392.0  423.443311  274.378911   15.60  206.4375  386.360
# cost_of_trip   359392.0  286.190113  157.993661   19.00  151.2000  282.480
# Profit         359392.0  137.253198  160.311840 -220.06   28.0120   81.962
#
#                     75%       max
# km_travelled    32.9600    48.000
# price_charged  583.6600  2048.030
# cost_of_trip   413.6832   691.200
# Profit         190.0300  1463.966

# %%
fig, axes = plt.subplots(2,2, figsize = (10,8), sharey = True)

for col, ax in zip(['km_travelled', 'price_charged', 'cost_of_trip', 'Profit'], 
                   axes.flatten()):
    
    sns.boxplot(x = col, data = Merged_data, y = 'company', ax = ax, palette=["#ff81c0","#ffff14"])
    plt.tight_layout();

# %%
#Groupby Year, and Company
year_df = Merged_data.groupby(["company", "year"]).agg({'Profit': sum, 'km_travelled': sum, "transaction_id" : "count"})

year_df.rename(columns={"transaction_id": "No of Customers", "km_travelled" : "KM"}, inplace=True)
#Profit per trip

year_df ['profit_trip']= round(year_df['Profit'] / year_df ['No of Customers'],2)
#Profit per KM travlled
year_df ['profit_km'] = round(year_df ['Profit'] / year_df ['KM'],2)

# %%
#Overall Profit by yearly
profit_yr= year_df.reset_index().pivot(columns='company', index='year', values='Profit')
profit_yr.index = profit_yr.index.astype(str)

#Create plot

fig = px.bar(profit_yr, labels=dict(value="Profit", Company="Cab Company"), color = 'company',  color_discrete_map={'Pink Cab':'#FC1CBF', 'Yellow Cab':'#FBE426'})
fig.update_layout(barmode="group")
fig.update_layout(title_text='Profit between 2016 and 2018 for Pink and Yellow Cab Company ')
fig.show('png')

# %%
#Avg_per KM
avg_km= year_df.reset_index().pivot(columns='company', index='year', values='profit_km')
avg_km.index = avg_km.index.astype(str)
#Avg per Trip
avg_trip= year_df.reset_index().pivot(columns='company', index='year', values='profit_trip')
avg_trip.index = avg_km.index.astype(str)

#Create subplot 
bar1 = px.bar(avg_km,
              labels=dict(value="Average Profit per KM", Company="Cab Company"), color = 'company',  color_discrete_map={ 'Pink Cab':'#FC1CBF', 'Yellow Cab':'#FBE426'})
bar2 = px.bar(avg_trip,
              labels=dict(value="Average Profit per KM", Company="Cab Company"), color = 'company',  color_discrete_map={'Pink Cab':'#FC1CBF', 'Yellow Cab':'#FBE426'})

# %%
fig = make_subplots(rows=1, cols=2, 
subplot_titles=("Average Profit per KM", "Average Profit per Customer"))
for trace in bar1.data:
    fig.add_trace(trace, 1, 1)
for trace in bar2.data:
    fig.add_trace(trace, 1, 2)

fig.update_layout(barmode="group")
fig.update_layout(title_text='Average Net Profit per KM and per Customer  between 2016 and 2018')

# edit axis labels
fig['layout']['xaxis']['title']='Year'
fig['layout']['xaxis2']['title']='Year'
fig['layout']['yaxis']['title']='Avg Profit per KM'
fig['layout']['yaxis2']['title']='Avg Profit per Ride'
fig.show('png')

# %%
Plot3 =  Merged_data.groupby(['company', 'month']).Profit.sum().to_frame('Profit')

# %%
Data_profit_per_year =  Merged_data.groupby(['company', 'year']).Profit.sum().to_frame('Profit')
plt.figure(figsize=(8,6))
sns.lineplot(x='year', y='Profit', hue="company", data=Data_profit_per_year , marker='o',palette=["#ff81c0","#ffff14"])
plt.xlabel("year", size=14)
plt.ylabel("Profit ", size=14)
plt.title("Profit  per year")
# Out:
# Text(0.5, 1.0, 'Profit  per year')

# %%
Data_profit_per_month =  Merged_data.groupby(['company', 'month']).Profit.sum().to_frame('Profit')
plt.figure(figsize=(8,6))
sns.lineplot(x='month', y='Profit', hue="company", data=Data_profit_per_month , marker='o',palette=["#ff81c0","#ffff14"])
plt.xlabel("year", size=14)
plt.ylabel("Profit ", size=14)
plt.title("Profit  per month")
# Out:
# Text(0.5, 1.0, 'Profit  per month')

# %%
Data_Pricechaged_per_year = Merged_data.groupby(['company', 'year'])['price_charged'].sum().to_frame('price')

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x='year', y='price', hue="company", data=Data_Pricechaged_per_year , marker='o', palette=["#ff81c0","#ffff14"])
plt.xlabel("year", size=14)
plt.ylabel("price_charged", size=14)
plt.title('price per year')
# Out:
# Text(0.5, 1.0, 'price per year')

# %%
Data_Pricechaged_per_month = Merged_data.groupby(['company', 'month'])['price_charged'].sum().to_frame('price')

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x='month', y='price', hue="company", data=Data_Pricechaged_per_month, marker='o',  palette=["#ff81c0","#ffff14"])
plt.xlabel("month", size=14)
plt.ylabel("price_charged", size=14)
plt.title('price per month')
# Out:
# Text(0.5, 1.0, 'price per month')

# %%
#Hypothesis thesis

# %% [markdown]
# # Hypothesis1
# H0 : There is no difference regarding Age for Yellow and Pink Cab
#
# H1 : There is difference regarding Age for both Yellow and Pink Cab

# %%
#Pink cab
First_dataset = Merged_data[(Merged_data.age<=50)&(Merged_data.company=='Pink Cab')].groupby('transaction_id').Profit.mean()
Second_dataset = Merged_data[(Merged_data.age>50)&(Merged_data.company=='Pink Cab')].groupby('transaction_id').Profit.mean()
print(First_dataset.shape[0],Second_dataset.shape[0])

from scipy import stats
_, p_value = stats.ttest_ind(First_dataset.values, Second_dataset.values,equal_var=True)
if(p_value<0.05):
    print('We accept alternate hypothesis that theres a difference')
else:
    print('We accept null hypothesis that theres no difference')
    
print('P value is ', p_value)
# Out:
# 71228 13483
# We accept null hypothesis that theres no difference
# P value is  0.32817487547980695

# %%
#Yellow Cab

First_dataset = Merged_data[(Merged_data.age<=50)&(Merged_data.company=='Yellow Cab')].groupby('transaction_id').Profit.mean()
Second_dataset = Merged_data[(Merged_data.age>50)&(Merged_data.company=='Yellow Cab')].groupby('transaction_id').Profit.mean()
print(First_dataset.shape[0],Second_dataset.shape[0])

from scipy import stats
_, p_value = stats.ttest_ind(First_dataset.values, Second_dataset.values,equal_var=True)
if(p_value<0.05):
    print('We accept alternate hypothesis that theres a difference')
else:
    print('We accept null hypothesis that theres no difference')
    
print('P value is ', p_value)
# Out:
# 231480 43201
# We accept alternate hypothesis that theres a difference
# P value is  6.494256817799368e-09

# %%
#Conduct t-test to measure the difference between Trasaction and Gender in both companies
#Yellow Cab 
Data_female = Merged_data[(Merged_data.gender=='Female')&(Merged_data.company=='Yellow Cab')].groupby('transaction_id').Profit.mean()
Data_Male = Merged_data[(Merged_data.gender=='Male')&(Merged_data.company=='Yellow Cab')].groupby('transaction_id').Profit.mean()
print(Data_female.shape[0],Data_Male.shape[0])


#import scipy to conduct testing hypothesis T-test
from scipy import stats

t, p_value = stats.ttest_ind(a = Data_female.values,b=Data_Male.values,equal_var=True)
if(p_value<0.05):
    print('We accept alternate hypothesis that there is a statistical difference in Yellow Cab between gender ')
else:
    print('We accept null hypothesis that there is no statistical difference in Yellow Cab between gender')
    
print('P value is ', p_value)


#Pink Cab
Data_female = Merged_data[(Merged_data.gender=='Female')&(Merged_data.company=='Pink Cab')].groupby('transaction_id').Profit.mean()
Data_Male = Merged_data[(Merged_data.gender=='Male')&(Merged_data.company=='Pink Cab')].groupby('transaction_id').Profit.mean()
print(Data_female.shape[0],Data_Male.shape[0])

t, p_value = stats.ttest_ind(a = Data_female.values,b=Data_Male.values,equal_var=True)
if(p_value<0.05):
    print('We accept alternate hypothesis that there is a statistical difference in Pink Cab between gender')
else:
    print('We accept null hypothesis that there is no statistical difference in Pink Cab between gender')
    
print('P value is ', p_value)
# Out:
# 116000 158681
# We accept alternate hypothesis that there is a statistical difference in Yellow Cab between gender
# P value is  6.060473042494144e-25
# 37480 47231
# We accept null hypothesis that there is no statistical difference in Pink Cab between gender
# P value is  0.11515305900425798
